# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
cococola = pd.read_excel("CocaCola_Sales_Rawdata.xlsx")

# %%
cococola
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
cococola.isnull().sum()
# Out:
# Quarter    0
# Sales      0
# dtype: int64

# %%
cococola.dtypes
# Out:
# Quarter     object
# Sales      float64
# dtype: object

# %%
cococola.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %%
cococola.plot()
# Out:
# <AxesSubplot:>

# %%
cococola.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Sales'}>]], dtype=object)

# %%
import seaborn as sns
sns.heatmap(cococola.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(cococola['Sales'])
# Out:
# C:\Users\shiji\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sales', ylabel='count'>

# %%
from pandas.plotting import lag_plot

lag_plot(cococola['Sales'])

plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.scatterplot(x='Sales',y='Quarter',data=cococola)
plt.title('DT vs ST')
plt.show()

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(cococola.Sales,lags=12)

tsa_plots.plot_pacf(cococola.Sales,lags=12)

plt.show()
# Out:
# C:\Users\shiji\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
cococola.plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
np.array(cococola["Sales"])
# Out:
# array([1734.82699966, 2244.96099854, 2533.80499268, 2154.96299744,
#        1547.81899643, 2104.41199493, 2014.36299896, 1991.74699783,
#        1869.04999924, 2313.63199615, 2128.31999969, 2026.82899857,
#        1910.60399628, 2331.16499329, 2206.54999542, 2173.96799469,
#        2148.27799988, 2739.30799866, 2792.7539978 , 2556.00999451,
#        2480.97399902, 3039.522995  , 3172.11599731, 2879.00099945,
#        2772.        , 3550.        , 3508.        , 3243.85999298,
#        3056.        , 3899.        , 3629.        , 3373.        ,
#        3352.        , 4342.        , 4461.        , 4017.        ,
#        3854.        , 4936.        , 4895.        , 4333.        ,
#        4194.        , 5253.        ])

# %%
import seaborn as sns
sns.set_theme()
rk= sns.distplot(cococola['Sales'],kde=True)
# Out:
# C:\Users\shiji\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from pandas.plotting import lag_plot
lag_plot(cococola['Sales'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
import numpy as np
quarter=['Q1','Q2','Q3','Q4']
n=cococola['Quarter'][0]
n[0:2]
# Out:
# 'Q1'

# %%
cococola['quarter']=0

# %%
for i in range(42):
    n=cococola['Quarter'][i]
    cococola['quarter'][i]=n[0:2]
# Out:
# C:\Users\shiji\AppData\Local\Temp\ipykernel_14688\1326245278.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cococola['quarter'][i]=n[0:2]

# %%
n
# Out:
# 'Q2_96'

# %%
dummy=pd.DataFrame(pd.get_dummies(cococola['quarter']))

# %%
cococola['quarter']
# Out:
# 0     Q1
# 1     Q2
# 2     Q3
# 3     Q4
# 4     Q1
# 5     Q2
# 6     Q3
# 7     Q4
# 8     Q1
# 9     Q2
# 10    Q3
# 11    Q4
# 12    Q1
# 13    Q2
# 14    Q3
# 15    Q4
# 16    Q1
# 17    Q2
# 18    Q3
# 19    Q4
# 20    Q1
# 21    Q2
# 22    Q3
# 23    Q4
# 24    Q1
# 25    Q2
# 26    Q3
# 27    Q4
# 28    Q1
# 29    Q2
# 30    Q3
# 31    Q4
# 32    Q1
# 33    Q2
# 34    Q3
# 35    Q4
# 36    Q1
# 37    Q2
# 38    Q3
# 39    Q4
# 40    Q1
# 41    Q2
# Name: quarter, dtype: object

# %%
coco=pd.concat((cococola,dummy),axis=1)
t= np.arange(1,43)
coco['t']=t
coco['t_square']=coco['t']*coco['t']

# %%
coco
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_square
# 0    Q1_86  1734.827000      Q1   1   0   0   0   1         1
# 1    Q2_86  2244.960999      Q2   0   1   0   0   2         4
# 2    Q3_86  2533.804993      Q3   0   0   1   0   3         9
# 3    Q4_86  2154.962997      Q4   0   0   0   1   4        16
# 4    Q1_87  1547.818996      Q1   1   0   0   0   5        25
# 5    Q2_87  2104.411995      Q2   0   1   0   0   6        36
# 6    Q3_87  2014.362999      Q3   0   0   1   0   7        49
# 7    Q4_87  1991.746998      Q4   0   0   0   1   8        64
# 8    Q1_88  1869.049999      Q1   1   0   0   0   9        81
# 9    Q2_88  2313.631996      Q2   0   1   0   0  10       100
# 10   Q3_88  2128.320000      Q3   0   0   1   0  11       121
# 11   Q4_88  2026.828999      Q4   0   0   0   1  12       144
# 12   Q1_89  1910.603996      Q1   1   0   0   0  13       169
# 13   Q2_89  2331.164993      Q2   0   1   0   0  14       196
# ...

# %%
log_Sales=np.log(coco['Sales'])
coco['log_Sales']=log_Sales

# %%
coco
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_square  log_Sales
# 0    Q1_86  1734.827000      Q1   1   0   0   0   1         1   7.458663
# 1    Q2_86  2244.960999      Q2   0   1   0   0   2         4   7.716443
# 2    Q3_86  2533.804993      Q3   0   0   1   0   3         9   7.837477
# 3    Q4_86  2154.962997      Q4   0   0   0   1   4        16   7.675529
# 4    Q1_87  1547.818996      Q1   1   0   0   0   5        25   7.344602
# 5    Q2_87  2104.411995      Q2   0   1   0   0   6        36   7.651791
# 6    Q3_87  2014.362999      Q3   0   0   1   0   7        49   7.608058
# 7    Q4_87  1991.746998      Q4   0   0   0   1   8        64   7.596767
# 8    Q1_88  1869.049999      Q1   1   0   0   0   9        81   7.533186
# 9    Q2_88  2313.631996      Q2   0   1   0   0  10       100   7.746574
# 10   Q3_88  2128.320000      Q3   0   0   1   0  11       121   7.663088
# 11   Q4_88  2026.828999      Q4   0   0   0   1  12       144   7.614228
# ...

# %%
train= coco.head(38)
test=coco.tail(4)
coco.Sales.plot()
# Out:
# <AxesSubplot:>

# %%
import statsmodels.formula.api as smf

# %%
test
# Out:
#    Quarter   Sales quarter  Q1  Q2  Q3  Q4   t  t_square  log_Sales
# 38   Q3_95  4895.0      Q3   0   0   1   0  39      1521   8.495970
# 39   Q4_95  4333.0      Q4   0   0   0   1  40      1600   8.374015
# 40   Q1_96  4194.0      Q1   1   0   0   0  41      1681   8.341410
# 41   Q2_96  5253.0      Q2   0   1   0   0  42      1764   8.566555

# %%
train
# Out:
#    Quarter        Sales quarter  Q1  Q2  Q3  Q4   t  t_square  log_Sales
# 0    Q1_86  1734.827000      Q1   1   0   0   0   1         1   7.458663
# 1    Q2_86  2244.960999      Q2   0   1   0   0   2         4   7.716443
# 2    Q3_86  2533.804993      Q3   0   0   1   0   3         9   7.837477
# 3    Q4_86  2154.962997      Q4   0   0   0   1   4        16   7.675529
# 4    Q1_87  1547.818996      Q1   1   0   0   0   5        25   7.344602
# 5    Q2_87  2104.411995      Q2   0   1   0   0   6        36   7.651791
# 6    Q3_87  2014.362999      Q3   0   0   1   0   7        49   7.608058
# 7    Q4_87  1991.746998      Q4   0   0   0   1   8        64   7.596767
# 8    Q1_88  1869.049999      Q1   1   0   0   0   9        81   7.533186
# 9    Q2_88  2313.631996      Q2   0   1   0   0  10       100   7.746574
# 10   Q3_88  2128.320000      Q3   0   0   1   0  11       121   7.663088
# 11   Q4_88  2026.828999      Q4   0   0   0   1  12       144   7.614228
# ...

# %%
linear= smf.ols('Sales~t',data=train).fit()
predlin=pd.Series(linear.predict(pd.DataFrame(test['t'])))
rmselin=np.sqrt((np.mean(np.array(test['Sales'])-np.array(predlin))**2))
rmselin
# Out:
# 421.17878760022745

# %%
quad=smf.ols('Sales~t+t_square',data=train).fit()
predquad=pd.Series(quad.predict(pd.DataFrame(test[['t','t_square']])))
rmsequad=np.sqrt(np.mean((np.array(test['Sales'])-np.array(predquad))**2))
rmsequad
# Out:
# 475.56183518315595

# %%
expo=smf.ols('log_Sales~t',data=train).fit()
predexp=pd.Series(expo.predict(pd.DataFrame(test['t'])))
predexp
rmseexpo=np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(predexp)))**2))
rmseexpo
# Out:
# 466.2479731067161

# %%
additive= smf.ols('Sales~ Q1+Q2+Q3+Q4',data=train).fit()
predadd=pd.Series(additive.predict(pd.DataFrame(test[['Q1','Q2','Q3','Q4']])))
predadd
rmseadd=np.sqrt(np.mean((np.array(test['Sales'])-np.array(predadd))**2))
rmseadd
# Out:
# 1860.0238154547274

# %%
addlinear= smf.ols('Sales~t+Q1+Q2+Q3+Q4',data=train).fit()
predaddlinear=pd.Series(addlinear.predict(pd.DataFrame(test[['t','Q1','Q2','Q3','Q4']])))
predaddlinear
# Out:
# 38    4292.265126
# 39    4066.761792
# 40    3961.769195
# 41    4639.214094
# dtype: float64

# %%
mulsea=smf.ols('log_Sales~Q1+Q2+Q3+Q4',data=train).fit()
predmul= pd.Series(mulsea.predict(pd.DataFrame(test[['Q1','Q2','Q3','Q4']])))
rmsemul= np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(predmul)))**2))
rmsemul
# Out:
# 1963.3896400779681

# %%
mullin= smf.ols('log_Sales~t+Q1+Q2+Q3+Q4',data=train).fit()
predmullin= pd.Series(mullin.predict(pd.DataFrame(test[['t','Q1','Q2','Q3','Q4']])))
rmsemulin=np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(predmullin)))**2))
rmsemulin
# Out:
# 225.52439049828146

# %%
mul_quad= smf.ols('log_Sales~t+t_square+Q1+Q2+Q3+Q4',data=train).fit()
pred_mul_quad= pd.Series(mul_quad.predict(test[['t','t_square','Q1','Q2','Q3','Q4']]))
rmse_mul_quad=np.sqrt(np.mean((np.array(test['Sales'])-np.array(np.exp(pred_mul_quad)))**2))
rmse_mul_quad
# Out:
# 581.8457187970074

# %%
data={'Model':pd.Series(['rmse_mul_quad','rmseadd','rmseaddlinear','rmseaddquad','rmseexpo','rmselin','rmsemul','rmsemulin','rmsequad']),'Values':pd.Series([rmse_mul_quad,rmseadd,rmseexpo,rmselin,rmsemul,rmsemulin,rmsequad])}
data
# Out:
# {'Model': 0    rmse_mul_quad
#  1          rmseadd
#  2    rmseaddlinear
#  3      rmseaddquad
#  4         rmseexpo
#  5          rmselin
#  6          rmsemul
#  7        rmsemulin
#  8         rmsequad
#  dtype: object,
#  'Values': 0     581.845719
#  1    1860.023815
#  2     466.247973
#  3     421.178788
#  4    1963.389640
#  5     225.524390
#  6     475.561835
#  dtype: float64}

# %%
Rmse=pd.DataFrame(data)
Rmse
# Out:
#            Model       Values
# 0  rmse_mul_quad   581.845719
# 1        rmseadd  1860.023815
# 2  rmseaddlinear   466.247973
# 3    rmseaddquad   421.178788
# 4       rmseexpo  1963.389640
# 5        rmselin   225.524390
# 6        rmsemul   475.561835
# 7      rmsemulin          NaN
# 8       rmsequad          NaN
